# %% [markdown]
# # Assignment 9

# %% [markdown]
# ## 1. SVM (Linearly Seperable Data)

# %% [markdown]
# ### You are given a two dimensional dataset (SVM_Q1) with 4 classes and you have to use SVM for classification.

# %% [markdown]
# ### Import the required libraries

# %%
# Imports library
from matplotlib import pyplot as plt
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.datasets import make_blobs
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### The code for loading data is given below.

# %%
# load data (do not change it)
import numpy as np
X_train, X_test, y_train, y_test = np.load('./SVM_Q1.npy', allow_pickle=True)

# %% [markdown]
# ### 1.a) Write code to visualize the training data

# %%
# Generate scatter plot for training data 
plt.scatter(X_train[:,0],X_train[:,1])

# %% [markdown]
# ### 1.b) Write the code for SVM classifier (you can write code from scratch or use sklrean)

# %%
# SVM classifier code here
model = SVC(kernel='linear', C =1000)
model.fit(X_train, y_train)
v = model.support_vectors_

# %% [markdown]
# ### 1.c) Generate the confusion matrix for the classifer on the test data

# %%
# Generate confusion matrix
y_pred = model.predict(X_test)
confusion_matrix(y_pred, y_test)
# Out:
# array([[326,   4,   3,   0],
#        [  4, 323,   0,   1],
#        [  6,   0, 335,   0],
#        [  0,   1,   2, 315]])

# %% [markdown]
# ### 1.d) Visualize the support vectors and decision boundary

# %%
plt.scatter(X_train[:,0],X_train[:,1])
plt.scatter(v[:,0], v[:,1])

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], c = y_train, s=30, cmap=plt.cm.Paired)

# plot the decision function
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

# create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = model.decision_function(xy)[:,0].reshape(XX.shape)

# plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
           linestyles=['--', '-', '--'])
# plot support vectors
ax.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1], s=100,
           linewidth=1, facecolors='none', edgecolors='k')
plt.title("First Decision boundary")
plt.show()

plt.scatter(X_train[:, 0], X_train[:, 1], c = y_train, s=30, cmap=plt.cm.Paired)

# plot the decision function
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

# create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = model.decision_function(xy)[:,1].reshape(XX.shape)

# plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
           linestyles=['--', '-', '--'])
# plot support vectors
ax.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1], s=100,
           linewidth=1, facecolors='none', edgecolors='k')
plt.title("Second Decision boundary")
plt.show()

plt.scatter(X_train[:, 0], X_train[:, 1], c = y_train, s=30, cmap=plt.cm.Paired)

# plot the decision function
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

# create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = model.decision_function(xy)[:,2].reshape(XX.shape)

# plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
           linestyles=['--', '-', '--'])
# plot support vectors
ax.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1], s=100,
           linewidth=1, facecolors='none', edgecolors='k')
plt.title("Third Decision boundary")
plt.show()

plt.scatter(X_train[:, 0], X_train[:, 1], c = y_train, s=30, cmap=plt.cm.Paired)

# plot the decision function
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

# create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = model.decision_function(xy)[:,3].reshape(XX.shape)

# plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
           linestyles=['--', '-', '--'])
# plot support vectors
ax.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1], s=100,
           linewidth=1, facecolors='none', edgecolors='k')
plt.title("Fourth Decision boundary")
plt.show()

# %% [markdown]
# ### 1.e) Report the accuracy obtained

# %%
# Code for Accuracy
accuracy_score(y_test,y_pred)*100
# Out:
# 98.4090909090909

# %% [markdown]
# ## 2. SVM (Non-linearly separable Data)

# %% [markdown]
# ### You are given a two dimensional dataset with 2 classes as loaded below and you have to use SVM for classification.

# %%
# generating data (do not change it)
from sklearn.datasets import make_circles 
X, Y = make_circles(n_samples = 3000, noise = 0.04) 
plt.scatter(X[:,0], X[:,1])
Y = Y[:,np.newaxis]

# %% [markdown]
# ### 2.a) Use train_test_split function in sklearn to split the dataset into train and test sets in the ratio of 80:20

# %%
# Code here
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ### 2.b) Write the code for SVM classifier with polynomial kernel (you can write code from scratch or use sklrean)
#
# Hint: Use kernel of degree 8.

# %%
# SVM code here
#Code here
clf = SVC(kernel='poly',degree=5)
clf.fit(X, Y)
# Out:
# /home/vishal/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# SVC(degree=5, kernel='poly')

# %% [markdown]
# ### 2.c) Generate the confusion matrix for the classifer on the test data

# %%
# Generate confusion matrix
confusion_matrix(y_pred, y_test)
# Out:
# array([[110,   3],
#        [193, 294]])

# %% [markdown]
# ### 2.d) Visualize the support vectors and plot the decision boundary

# %%
# Visualize support vectors
plt.scatter(X[:, 0], X[:, 1], c=Y, s=50, cmap='autumn')
plot_svc_decision_function(clf)
plt.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1],
           s=300, lw=1, facecolors='none');
y_pred = clf.predict(X_test)

# %% [markdown]
# ### 2.e) Report the accuracy obtained

# %%
# Accuracy code
print("Accuracy:", accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 0.6733333333333333

# %% [markdown]
# ### 2.f) Repeat the above steps with sigmoid kernel (you can write code from scratch or use sklearn). You can tune the parameter to obtain better accuracy on test set.

# %%
#Code here
clf = SVC(kernel='sigmoid', degree =5)
clf.fit(X, Y)
plt.scatter(X[:, 0], X[:, 1], c=Y, s=50, cmap='autumn')
plot_svc_decision_function(clf)
plt.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1],
           s=300, lw=1, facecolors='none');
y_pred = clf.predict(X_test)
print("Accuracy:", accuracy_score(y_test,y_pred))
# Out:
# /home/vishal/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Accuracy: 0.5283333333333333

# %% [markdown]
# ### 2.g) Reapeat the steps 2.c to 2.g with  radial basis function kernel (you can write code from scratch or use sklrean). You can tune the parameter to obtain better accuracy on test set.

# %%
# Code here
clf = SVC(kernel='rbf',C = 10000)
clf.fit(X, Y)
plt.scatter(X[:, 0], X[:, 1], c=Y, s=50, cmap='autumn')
plot_svc_decision_function(clf)
plt.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1],
            s=300, lw=1, facecolors='none');
y_pred = clf.predict(X_test)
print("Accuracy:", accuracy_score(y_test,y_pred))
# Out:
# /home/vishal/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Accuracy: 0.9916666666666667

# %% [markdown]
# ### 2.h) For which kernal in SVM, you have obtained the highest and lowest  accuracy? What do you think the reason for it?

# %% [markdown]
# # Answer here
# Radial basis function has the highest accuracy whereas sigmoid is the lowest. RBF is more sutiable in this case as it uses normal curves around the data points, and sums these so that the decision boundary can be defined by a type of topology condition. Sigmoid on the other hand due to the tan fn, mislabels the support vectors
